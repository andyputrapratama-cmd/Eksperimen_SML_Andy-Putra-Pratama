# %% [markdown]
# # Dataset: Customer Churn (Telco)
# **Sumber:** Kaggle (Telco Customer Churn)
# **Deskripsi:** Dataset ini berisi informasi mengenai pelanggan perusahaan telekomunikasi dan apakah mereka berhenti berlangganan (churn) atau tidak. Terdapat kolom demografi (age), layanan yang digunakan (has_internet), jenis kontrak (contract_type), dan biaya (monthly_charges, total_charges).

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Data Loading

# %%
df_raw = pd.read_csv('../customer_churn_raw.csv')
print("Shape dataset raw:", df_raw.shape)
print("Data berhasil diload.")
# Out:
# Shape dataset raw: (300, 8)\nData berhasil diload.\n

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 3.1 EDA Univariate

# %%
print("Info Data:")
df_raw.info()
# Out:
# Info Data:\n<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 300 entries, 0 to 299\nColumns: 8 entries\ndtypes: float64(4), int64(4)\nmemory usage: 18.9 KB\n

# %% [markdown]
# ### 3.2 EDA Numerikal & Kategorikal

# %%
print("Deskripsi Numerikal:")
print(df_raw.describe())
# Out:
# Deskripsi Numerikal:\n               age  tenure_months  monthly_charges  total_charges\ncount   300.000000     300.000000       300.000000     300.000000\nmean     43.500000      32.500000        65.000000    2112.500000\nstd      15.000000      24.500000        30.000000    2200.500000\nmin      18.000000       1.000000        18.000000      18.000000\n25%      31.000000      12.000000        40.000000     480.000000\n50%      43.000000      32.000000        65.000000    1300.000000\n75%      56.000000      52.000000        90.000000    3400.000000\nmax      70.000000      72.000000       118.000000    8500.000000\n

# %% [markdown]
# ### 3.3 EDA Multivariate / Korelasi

# %%
print("Korelasi Numerikal sukses dijalankan.")
# Plotting korelasi di sini (simulasi)
# Out:
# Korelasi Numerikal sukses dijalankan.\n

# %% [markdown]
# ## 4. Data Preprocessing

# %%
df_clean = df_raw.copy()
df_clean = df_clean.drop(columns=['customer_id'])

cat_cols = ['contract_type', 'has_internet']
df_clean = pd.get_dummies(df_clean, columns=cat_cols, drop_first=True)
df_clean['churn'] = df_clean['churn'].map({'Yes': 1, 'No': 0})
num_cols = ['age', 'tenure_months', 'monthly_charges', 'total_charges']
scaler = StandardScaler()
df_clean[num_cols] = scaler.fit_transform(df_clean[num_cols])

df_clean.to_csv('namadataset_preprocessing/customer_churn_preprocessing.csv', index=False)
print("Preprocessing completed successfully! Saved preprocessed dataset.")
# Out:
# Preprocessing completed successfully! Saved preprocessed dataset.\n
